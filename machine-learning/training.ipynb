# %%
import pandas as pd

df = pd.read_csv('diabetes_prediction_dataset.csv')

# %%
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# 1              6.6                   80         0
# 2              5.7                  158         0
# 3              5.0                  155         0
# 4              4.8                  155         0
# ...            ...                  ...       ...
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0
#
# [100000 rows x 9 columns]

# %%
df['smoking_history'].value_counts()
# Out:
# No Info        35816
# never          35095
# former          9352
# current         9286
# not current     6447
# ever            4004
# Name: smoking_history, dtype: int64

# %%
df.drop('smoking_history', axis=1, inplace=True)

# %%
df['diabetes'].value_counts()
# Out:
# 0    91500
# 1     8500
# Name: diabetes, dtype: int64

# %%
df_filtered = df[df['gender'] != 'Other']

# %%
df_encoded = pd.get_dummies(df_filtered, columns=['gender'], prefix=['gender'])

# %%
df_encoded
# Out:
#         age  hypertension  heart_disease    bmi  HbA1c_level  \
# 0      80.0             0              1  25.19          6.6
# 1      54.0             0              0  27.32          6.6
# 2      28.0             0              0  27.32          5.7
# 3      36.0             0              0  23.45          5.0
# 4      76.0             1              1  20.14          4.8
# ...     ...           ...            ...    ...          ...
# 99995  80.0             0              0  27.32          6.2
# 99996   2.0             0              0  17.37          6.5
# 99997  66.0             0              0  27.83          5.7
# 99998  24.0             0              0  35.42          4.0
# 99999  57.0             0              0  22.43          6.6
#
#        blood_glucose_level  diabetes  gender_Female  gender_Male
# 0                      140         0              1            0
# 1                       80         0              1            0
# 2                      158         0              0            1
# 3                      155         0              1            0
# 4                      155         0              0            1
# ...                    ...       ...            ...          ...
# 99995                   90         0              1            0
# 99996                  100         0              1            0
# 99997                  155         0              0            1
# 99998                  100         0              1            0
# 99999                   90         0              1            0
#
# [99982 rows x 9 columns]

# %%
import numpy as np
from imblearn.over_sampling import SMOTE
from sklearn.datasets import make_classification

X = df_encoded.drop('diabetes', axis=1)
y = df_encoded['diabetes']

# Instantiate the SMOTE object
smote = SMOTE(sampling_strategy='auto', random_state=42)

# Fit and apply SMOTE to the dataset
X_resampled, y_resampled = smote.fit_resample(X, y)

# Check the class distribution after oversampling
print("Class distribution after SMOTE:")
unique, counts = np.unique(y_resampled, return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# Class distribution after SMOTE:
# {0: 91482, 1: 91482}

# %%
oversampled_df = pd.DataFrame(data=X_resampled, columns=X.columns)
oversampled_df['diabetes'] = y_resampled

# %%
from pycaret.classification import *

# Load a sample classification dataset (replace with your own dataset)
from pycaret.datasets import get_data

# Initialize the PyCaret setup
clf_setup = setup(data=oversampled_df, target='diabetes')

# Compare different models
compare_models()
# Out:
# <style type="text/css">
# #T_86764_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_86764" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86764_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_86764_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86764_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_86764_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_86764_row0_col1" class="data row0 col1" >6155</td>
#     </tr>
#     <tr>
#       <th id="T_86764_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_86764_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_86764_row1_col1" class="data row1 col1" >diabetes</td>
#     </tr>
#     <tr>
#       <th id="T_86764_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_86764_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_86764_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_86764_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_86764_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_86764_row3_col1" class="data row3 col1" >(182964, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_86764_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_86764_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_86764_row4_col1" class="data row4 col1" >(182964, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_86764_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_86764_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_86764_row5_col1" class="data row5 col1" >(128074, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_86764_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_86764_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_86764_row6_col1" class="data row6 col1" >(54890, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_86764_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_86764_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_86764_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_86764_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_86764_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_86764_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_86764_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_86764_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_86764_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_86764_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_86764_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_86764_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_86764_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_86764_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_86764_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_86764_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_86764_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_86764_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_86764_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_86764_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_86764_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_86764_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_86764_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_86764_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_86764_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_86764_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_86764_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_86764_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_86764_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_86764_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_86764_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_86764_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_86764_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_86764_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_86764_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_86764_row18_col1" class="data row18 col1" >bc5b</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a8934 th {
#   text-align: left;
# }
# #T_a8934_row0_col0, #T_a8934_row0_col3, #T_a8934_row0_col4, #T_a8934_row1_col0, #T_a8934_row1_col1, #T_a8934_row1_col2, #T_a8934_row1_col3, #T_a8934_row1_col5, #T_a8934_row1_col6, #T_a8934_row1_col7, #T_a8934_row2_col0, #T_a8934_row2_col1, #T_a8934_row2_col2, #T_a8934_row2_col4, #T_a8934_row2_col5, #T_a8934_row2_col6, #T_a8934_row2_col7, #T_a8934_row3_col0, #T_a8934_row3_col1, #T_a8934_row3_col2, #T_a8934_row3_col3, #T_a8934_row3_col4, #T_a8934_row3_col5, #T_a8934_row3_col6, #T_a8934_row3_col7, #T_a8934_row4_col0, #T_a8934_row4_col1, #T_a8934_row4_col2, #T_a8934_row4_col3, #T_a8934_row4_col4, #T_a8934_row4_col5, #T_a8934_row4_col6, #T_a8934_row4_col7, #T_a8934_row5_col0, #T_a8934_row5_col1, #T_a8934_row5_col2, #T_a8934_row5_col3, #T_a8934_row5_col4, #T_a8934_row5_col5, #T_a8934_row5_col6, #T_a8934_row5_col7, #T_a8934_row6_col0, #T_a8934_row6_col1, #T_a8934_row6_col2, #T_a8934_row6_col3, #T_a8934_row6_col4, #T_a8934_row6_col5, #T_a8934_row6_col6, #T_a8934_row6_col7, #T_a8934_row7_col0, #T_a8934_row7_col1, #T_a8934_row7_col2, #T_a8934_row7_col3, #T_a8934_row7_col4, #T_a8934_row7_col5, #T_a8934_row7_col6, #T_a8934_row7_col7, #T_a8934_row8_col0, #T_a8934_row8_col1, #T_a8934_row8_col2, #T_a8934_row8_col3, #T_a8934_row8_col4, #T_a8934_row8_col5, #T_a8934_row8_col6, #T_a8934_row8_col7, #T_a8934_row9_col0, #T_a8934_row9_col1, #T_a8934_row9_col2, #T_a8934_row9_col3, #T_a8934_row9_col4, #T_a8934_row9_col5, #T_a8934_row9_col6, #T_a8934_row9_col7, #T_a8934_row10_col0, #T_a8934_row10_col1, #T_a8934_row10_col2, #T_a8934_row10_col3, #T_a8934_row10_col4, #T_a8934_row10_col5, #T_a8934_row10_col6, #T_a8934_row10_col7, #T_a8934_row11_col0, #T_a8934_row11_col1, #T_a8934_row11_col2, #T_a8934_row11_col3, #T_a8934_row11_col4, #T_a8934_row11_col5, #T_a8934_row11_col6, #T_a8934_row11_col7, #T_a8934_row12_col0, #T_a8934_row12_col1, #T_a8934_row12_col2, #T_a8934_row12_col3, #T_a8934_row12_col4, #T_a8934_row12_col5, #T_a8934_row12_col6, #T_a8934_row12_col7, #T_a8934_row13_col0, #T_a8934_row13_col1, #T_a8934_row13_col2, #T_a8934_row13_col3, #T_a8934_row13_col4, #T_a8934_row13_col5, #T_a8934_row13_col6, #T_a8934_row13_col7, #T_a8934_row14_col0, #T_a8934_row14_col1, #T_a8934_row14_col2, #T_a8934_row14_col3, #T_a8934_row14_col4, #T_a8934_row14_col5, #T_a8934_row14_col6, #T_a8934_row14_col7 {
#   text-align: left;
# }
# #T_a8934_row0_col1, #T_a8934_row0_col2, #T_a8934_row0_col5, #T_a8934_row0_col6, #T_a8934_row0_col7, #T_a8934_row1_col4, #T_a8934_row2_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_a8934_row0_col8, #T_a8934_row1_col8, #T_a8934_row2_col8, #T_a8934_row3_col8, #T_a8934_row4_col8, #T_a8934_row5_col8, #T_a8934_row6_col8, #T_a8934_row7_col8, #T_a8934_row8_col8, #T_a8934_row9_col8, #T_a8934_row10_col8, #T_a8934_row11_col8, #T_a8934_row12_col8, #T_a8934_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_a8934_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_a8934" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8934_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a8934_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_a8934_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_a8934_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_a8934_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_a8934_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_a8934_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_a8934_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_a8934_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8934_level0_row0" class="row_heading level0 row0" >xgboost</th>
#       <td id="T_a8934_row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
#       <td id="T_a8934_row0_col1" class="data row0 col1" >0.9787</td>
#       <td id="T_a8934_row0_col2" class="data row0 col2" >0.9975</td>
#       <td id="T_a8934_row0_col3" class="data row0 col3" >0.9630</td>
#       <td id="T_a8934_row0_col4" class="data row0 col4" >0.9942</td>
#       <td id="T_a8934_row0_col5" class="data row0 col5" >0.9784</td>
#       <td id="T_a8934_row0_col6" class="data row0 col6" >0.9574</td>
#       <td id="T_a8934_row0_col7" class="data row0 col7" >0.9579</td>
#       <td id="T_a8934_row0_col8" class="data row0 col8" >6.1020</td>
#     </tr>
#     <tr>
#       <th id="T_a8934_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_a8934_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_a8934_row1_col1" class="data row1 col1" >0.9756</td>
#       <td id="T_a8934_row1_col2" class="data row1 col2" >0.9973</td>
#       <td id="T_a8934_row1_col3" class="data row1 col3" >0.9556</td>
#       <td id="T_a8934_row1_col4" class="data row1 col4" >0.9953</td>
#       <td id="T_a8934_row1_col5" class="data row1 col5" >0.9751</td>
#       <td id="T_a8934_row1_col6" class="data row1 col6" >0.9511</td>
#       <td id="T_a8934_row1_col7" class="data row1 col7" >0.9519</td>
#       <td id="T_a8934_row1_col8" class="data row1 col8" >3.6840</td>
#     </tr>
#     <tr>
#       <th id="T_a8934_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_a8934_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_a8934_row2_col1" class="data row2 col1" >0.9741</td>
#       <td id="T_a8934_row2_col2" class="data row2 col2" >0.9958</td>
#       <td id="T_a8934_row2_col3" class="data row2 col3" >0.9729</td>
#       <td id="T_a8934_row2_col4" class="data row2 col4" >0.9752</td>
#       <td id="T_a8934_row2_col5" class="data row2 col5" >0.9741</td>
#       <td id="T_a8934_row2_col6" class="data row2 col6" >0.9482</td>
#       <td id="T_a8934_row2_col7" class="data row2 col7" >0.9482</td>
#       <td id="T_a8934_row2_col8" class="data row2 col8" >4.0890</td>
#     </tr>
#     <tr>
#       <th id="T_a8934_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_a8934_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_a8934_row3_col1" class="data row3 col1" >0.9737</td>
#       <td id="T_a8934_row3_col2" class="data row3 col2" >0.9970</td>
#       <td id="T_a8934_row3_col3" class="data row3 col3" >0.9701</td>
#       <td id="T_a8934_row3_col4" class="data row3 col4" >0.9772</td>
#       <td id="T_a8934_row3_col5" class="data row3 col5" >0.9736</td>
#       <td id="T_a8934_row3_col6" class="data row3 col6" >0.9474</td>
#       <td id="T_a8934_row3_col7" class="data row3 col7" >0.9474</td>
#       <td id="T_a8934_row3_col8" class="data row3 col8" >6.0780</td>
#     </tr>
#     <tr>
#       <th id="T_a8934_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_a8934_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_a8934_row4_col1" class="data row4 col1" >0.9702</td>
#       <td id="T_a8934_row4_col2" class="data row4 col2" >0.9960</td>
#       <td id="T_a8934_row4_col3" class="data row4 col3" >0.9508</td>
#       <td id="T_a8934_row4_col4" class="data row4 col4" >0.9892</td>
#       <td id="T_a8934_row4_col5" class="data row4 col5" >0.9696</td>
#       <td id="T_a8934_row4_col6" class="data row4 col6" >0.9404</td>
#       <td id="T_a8934_row4_col7" class="data row4 col7" >0.9411</td>
#       <td id="T_a8934_row4_col8" class="data row4 col8" >8.8430</td>
#     </tr>
#     <tr>
#       <th id="T_a8934_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_a8934_row5_col0" class="data row5 col0" >Decision Tree Classifier</td>
#       <td id="T_a8934_row5_col1" class="data row5 col1" >0.9689</td>
#       <td id="T_a8934_row5_col2" class="data row5 col2" >0.9693</td>
#       <td id="T_a8934_row5_col3" class="data row5 col3" >0.9703</td>
#       <td id="T_a8934_row5_col4" class="data row5 col4" >0.96
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=-1, num_parallel_tree=None,
#               objective='binary:logistic', predictor=None, ...)

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, f1_score

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

# Create an ExtraTreesClassifier
extra_trees = ExtraTreesClassifier(random_state=42)

# Train the classifier on the training data
extra_trees.fit(X_train, y_train)

# Make predictions on the training and test data
y_train_pred = extra_trees.predict(X_train)
y_test_pred = extra_trees.predict(X_test)

# Calculate and print metrics for the training set
train_accuracy = accuracy_score(y_train, y_train_pred)
train_recall = recall_score(y_train, y_train_pred, average='weighted')
train_f1 = f1_score(y_train, y_train_pred, average='weighted')

print("Training Metrics:")
print(f"Accuracy: {train_accuracy:.2f}")
print(f"Recall: {train_recall:.2f}")
print(f"F1-score: {train_f1:.2f}")

# Calculate and print metrics for the test set
test_accuracy = accuracy_score(y_test, y_test_pred)
test_recall = recall_score(y_test, y_test_pred, average='weighted')
test_f1 = f1_score(y_test, y_test_pred, average='weighted')

print("\nTesting Metrics:")
print(f"Accuracy: {test_accuracy:.2f}")
print(f"Recall: {test_recall:.2f}")
print(f"F1-score: {test_f1:.2f}")
# Out:
# Training Metrics:
# Accuracy: 1.00
# Recall: 1.00
# F1-score: 1.00
#
# Testing Metrics:
# Accuracy: 0.97
# Recall: 0.97
# F1-score: 0.96

# %%
from imblearn.under_sampling import RandomUnderSampler

# Instantiate the RandomUnderSampler object
under_sampler = RandomUnderSampler(sampling_strategy='auto', random_state=42)

# Fit and apply undersampling to the dataset
X_resampled, y_resampled = under_sampler.fit_resample(X, y)

# Check the class distribution after undersampling
print("Class distribution after undersampling:")
unique, counts = np.unique(y_resampled, return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# Class distribution after undersampling:
# {0: 8500, 1: 8500}

# %%
undersampled = pd.DataFrame(data=X_resampled, columns=X.columns)
undersampled['diabetes'] = y_resampled

# %%
from pycaret.classification import *

# Load a sample classification dataset (replace with your own dataset)
from pycaret.datasets import get_data

# Initialize the PyCaret setup
clf_setup = setup(data=undersampled, target='diabetes')

# Compare different models
compare_models()
# Out:
# <style type="text/css">
# #T_0f547_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0f547" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0f547_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0f547_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f547_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0f547_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_0f547_row0_col1" class="data row0 col1" >4254</td>
#     </tr>
#     <tr>
#       <th id="T_0f547_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0f547_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_0f547_row1_col1" class="data row1 col1" >diabetes</td>
#     </tr>
#     <tr>
#       <th id="T_0f547_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0f547_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_0f547_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_0f547_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0f547_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_0f547_row3_col1" class="data row3 col1" >(17000, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_0f547_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0f547_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_0f547_row4_col1" class="data row4 col1" >(17000, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_0f547_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0f547_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_0f547_row5_col1" class="data row5 col1" >(11900, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_0f547_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0f547_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_0f547_row6_col1" class="data row6 col1" >(5100, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_0f547_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0f547_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_0f547_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_0f547_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0f547_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_0f547_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_0f547_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0f547_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_0f547_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_0f547_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0f547_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_0f547_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_0f547_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0f547_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_0f547_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_0f547_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0f547_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_0f547_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_0f547_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0f547_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_0f547_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_0f547_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0f547_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_0f547_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_0f547_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_0f547_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_0f547_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0f547_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_0f547_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_0f547_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0f547_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_0f547_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_0f547_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_0f547_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_0f547_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_0f547_row18_col1" class="data row18 col1" >57f3</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_efe9d th {
#   text-align: left;
# }
# #T_efe9d_row0_col0, #T_efe9d_row0_col4, #T_efe9d_row1_col0, #T_efe9d_row1_col1, #T_efe9d_row1_col2, #T_efe9d_row1_col3, #T_efe9d_row1_col5, #T_efe9d_row1_col6, #T_efe9d_row1_col7, #T_efe9d_row2_col0, #T_efe9d_row2_col1, #T_efe9d_row2_col2, #T_efe9d_row2_col3, #T_efe9d_row2_col4, #T_efe9d_row2_col5, #T_efe9d_row2_col6, #T_efe9d_row2_col7, #T_efe9d_row3_col0, #T_efe9d_row3_col1, #T_efe9d_row3_col2, #T_efe9d_row3_col3, #T_efe9d_row3_col4, #T_efe9d_row3_col5, #T_efe9d_row3_col6, #T_efe9d_row3_col7, #T_efe9d_row4_col0, #T_efe9d_row4_col1, #T_efe9d_row4_col2, #T_efe9d_row4_col3, #T_efe9d_row4_col4, #T_efe9d_row4_col5, #T_efe9d_row4_col6, #T_efe9d_row4_col7, #T_efe9d_row5_col0, #T_efe9d_row5_col1, #T_efe9d_row5_col2, #T_efe9d_row5_col3, #T_efe9d_row5_col4, #T_efe9d_row5_col5, #T_efe9d_row5_col6, #T_efe9d_row5_col7, #T_efe9d_row6_col0, #T_efe9d_row6_col1, #T_efe9d_row6_col2, #T_efe9d_row6_col3, #T_efe9d_row6_col4, #T_efe9d_row6_col5, #T_efe9d_row6_col6, #T_efe9d_row6_col7, #T_efe9d_row7_col0, #T_efe9d_row7_col1, #T_efe9d_row7_col2, #T_efe9d_row7_col3, #T_efe9d_row7_col4, #T_efe9d_row7_col5, #T_efe9d_row7_col6, #T_efe9d_row7_col7, #T_efe9d_row8_col0, #T_efe9d_row8_col1, #T_efe9d_row8_col2, #T_efe9d_row8_col3, #T_efe9d_row8_col4, #T_efe9d_row8_col5, #T_efe9d_row8_col6, #T_efe9d_row8_col7, #T_efe9d_row9_col0, #T_efe9d_row9_col1, #T_efe9d_row9_col2, #T_efe9d_row9_col3, #T_efe9d_row9_col4, #T_efe9d_row9_col5, #T_efe9d_row9_col6, #T_efe9d_row9_col7, #T_efe9d_row10_col0, #T_efe9d_row10_col1, #T_efe9d_row10_col2, #T_efe9d_row10_col3, #T_efe9d_row10_col4, #T_efe9d_row10_col5, #T_efe9d_row10_col6, #T_efe9d_row10_col7, #T_efe9d_row11_col0, #T_efe9d_row11_col1, #T_efe9d_row11_col2, #T_efe9d_row11_col3, #T_efe9d_row11_col4, #T_efe9d_row11_col5, #T_efe9d_row11_col6, #T_efe9d_row11_col7, #T_efe9d_row12_col0, #T_efe9d_row12_col1, #T_efe9d_row12_col2, #T_efe9d_row12_col3, #T_efe9d_row12_col4, #T_efe9d_row12_col5, #T_efe9d_row12_col6, #T_efe9d_row12_col7, #T_efe9d_row13_col0, #T_efe9d_row13_col1, #T_efe9d_row13_col2, #T_efe9d_row13_col3, #T_efe9d_row13_col4, #T_efe9d_row13_col5, #T_efe9d_row13_col6, #T_efe9d_row13_col7, #T_efe9d_row14_col0, #T_efe9d_row14_col1, #T_efe9d_row14_col2, #T_efe9d_row14_col3, #T_efe9d_row14_col4, #T_efe9d_row14_col5, #T_efe9d_row14_col6, #T_efe9d_row14_col7 {
#   text-align: left;
# }
# #T_efe9d_row0_col1, #T_efe9d_row0_col2, #T_efe9d_row0_col3, #T_efe9d_row0_col5, #T_efe9d_row0_col6, #T_efe9d_row0_col7, #T_efe9d_row1_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_efe9d_row0_col8, #T_efe9d_row1_col8, #T_efe9d_row2_col8, #T_efe9d_row3_col8, #T_efe9d_row4_col8, #T_efe9d_row5_col8, #T_efe9d_row6_col8, #T_efe9d_row7_col8, #T_efe9d_row8_col8, #T_efe9d_row9_col8, #T_efe9d_row10_col8, #T_efe9d_row11_col8, #T_efe9d_row12_col8, #T_efe9d_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_efe9d_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_efe9d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_efe9d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_efe9d_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_efe9d_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_efe9d_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_efe9d_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_efe9d_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_efe9d_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_efe9d_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_efe9d_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_efe9d_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_efe9d_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_efe9d_row0_col1" class="data row0 col1" >0.9130</td>
#       <td id="T_efe9d_row0_col2" class="data row0 col2" >0.9795</td>
#       <td id="T_efe9d_row0_col3" class="data row0 col3" >0.9346</td>
#       <td id="T_efe9d_row0_col4" class="data row0 col4" >0.8962</td>
#       <td id="T_efe9d_row0_col5" class="data row0 col5" >0.9149</td>
#       <td id="T_efe9d_row0_col6" class="data row0 col6" >0.8261</td>
#       <td id="T_efe9d_row0_col7" class="data row0 col7" >0.8270</td>
#       <td id="T_efe9d_row0_col8" class="data row0 col8" >0.6830</td>
#     </tr>
#     <tr>
#       <th id="T_efe9d_level0_row1" class="row_heading level0 row1" >ada</th>
#       <td id="T_efe9d_row1_col0" class="data row1 col0" >Ada Boost Classifier</td>
#       <td id="T_efe9d_row1_col1" class="data row1 col1" >0.9085</td>
#       <td id="T_efe9d_row1_col2" class="data row1 col2" >0.9790</td>
#       <td id="T_efe9d_row1_col3" class="data row1 col3" >0.9190</td>
#       <td id="T_efe9d_row1_col4" class="data row1 col4" >0.9004</td>
#       <td id="T_efe9d_row1_col5" class="data row1 col5" >0.9095</td>
#       <td id="T_efe9d_row1_col6" class="data row1 col6" >0.8170</td>
#       <td id="T_efe9d_row1_col7" class="data row1 col7" >0.8174</td>
#       <td id="T_efe9d_row1_col8" class="data row1 col8" >0.2390</td>
#     </tr>
#     <tr>
#       <th id="T_efe9d_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_efe9d_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_efe9d_row2_col1" class="data row2 col1" >0.9074</td>
#       <td id="T_efe9d_row2_col2" class="data row2 col2" >0.9783</td>
#       <td id="T_efe9d_row2_col3" class="data row2 col3" >0.9192</td>
#       <td id="T_efe9d_row2_col4" class="data row2 col4" >0.8983</td>
#       <td id="T_efe9d_row2_col5" class="data row2 col5" >0.9085</td>
#       <td id="T_efe9d_row2_col6" class="data row2 col6" >0.8148</td>
#       <td id="T_efe9d_row2_col7" class="data row2 col7" >0.8153</td>
#       <td id="T_efe9d_row2_col8" class="data row2 col8" >0.7240</td>
#     </tr>
#     <tr>
#       <th id="T_efe9d_level0_row3" class="row_heading level0 row3" >xgboost</th>
#       <td id="T_efe9d_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_efe9d_row3_col1" class="data row3 col1" >0.9045</td>
#       <td id="T_efe9d_row3_col2" class="data row3 col2" >0.9771</td>
#       <td id="T_efe9d_row3_col3" class="data row3 col3" >0.9131</td>
#       <td id="T_efe9d_row3_col4" class="data row3 col4" >0.8978</td>
#       <td id="T_efe9d_row3_col5" class="data row3 col5" >0.9053</td>
#       <td id="T_efe9d_row3_col6" class="data row3 col6" >0.8089</td>
#       <td id="T_efe9d_row3_col7" class="data row3 col7" >0.8092</td>
#       <td id="T_efe9d_row3_col8" class="data row3 col8" >0.6180</td>
#     </tr>
#     <tr>
#       <th id="T_efe9d_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_efe9d_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_efe9d_row4_col1" class="data row4 col1" >0.9012</td>
#       <td id="T_efe9d_row4_col2" class="data row4 col2" >0.9728</td>
#       <td id="T_efe9d_row4_col3" class="data row4 col3" >0.9074</td>
#       <td id="T_efe9d_row4_col4" class="data row4 col4" >0.8964</td>
#       <td id="T_efe9d_row4_col5" class="data row4 col5" >0.9018</td>
#       <td id="T_efe9d_row4_col6" class="data row4 col6" >0.8024</td>
#       <td id="T_efe9d_row4_col7" class="data row4 col7" >0.8025</td>
#       <td id="T_efe9d_row4_col8" class="data row4 col8" >0.4790</td>
#     </tr>
#     <tr>
#       <th id="T_efe9d_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_efe9d_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_efe9d_row5_col1" class="data row5 col1" >0.8987</td>
#       <td id="T_efe9d_row5_col2" class="data row5 col2" >0.9639</td>
#       <td id="T_efe9d_row5_col3" class="data row5 col3" >0.9066</td>
#       <td id="T_efe9d_row5_col4" class="data row5 col4" >0.8926<
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='log_loss', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_samples_leaf=1,
#                            min_samples_split=2, min_weight_fraction_leaf=0.0,
#                            n_estimators=100, n_iter_no_change=None,
#                            random_state=4254, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
rf_model = create_model('rf')

# Tune the model
tuned_rf_model = tune_model(rf_model)

# Evaluate the model on the test set
evaluate_model(tuned_rf_model)
# Out:
# <style type="text/css">
# #T_88d50_row10_col0, #T_88d50_row10_col1, #T_88d50_row10_col2, #T_88d50_row10_col3, #T_88d50_row10_col4, #T_88d50_row10_col5, #T_88d50_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_88d50" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88d50_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_88d50_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_88d50_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_88d50_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_88d50_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_88d50_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_88d50_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88d50_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_88d50_row0_col0" class="data row0 col0" >0.8958</td>
#       <td id="T_88d50_row0_col1" class="data row0 col1" >0.9701</td>
#       <td id="T_88d50_row0_col2" class="data row0 col2" >0.8874</td>
#       <td id="T_88d50_row0_col3" class="data row0 col3" >0.9026</td>
#       <td id="T_88d50_row0_col4" class="data row0 col4" >0.8949</td>
#       <td id="T_88d50_row0_col5" class="data row0 col5" >0.7916</td>
#       <td id="T_88d50_row0_col6" class="data row0 col6" >0.7917</td>
#     </tr>
#     <tr>
#       <th id="T_88d50_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_88d50_row1_col0" class="data row1 col0" >0.8924</td>
#       <td id="T_88d50_row1_col1" class="data row1 col1" >0.9716</td>
#       <td id="T_88d50_row1_col2" class="data row1 col2" >0.9092</td>
#       <td id="T_88d50_row1_col3" class="data row1 col3" >0.8797</td>
#       <td id="T_88d50_row1_col4" class="data row1 col4" >0.8942</td>
#       <td id="T_88d50_row1_col5" class="data row1 col5" >0.7849</td>
#       <td id="T_88d50_row1_col6" class="data row1 col6" >0.7853</td>
#     </tr>
#     <tr>
#       <th id="T_88d50_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_88d50_row2_col0" class="data row2 col0" >0.8866</td>
#       <td id="T_88d50_row2_col1" class="data row2 col1" >0.9645</td>
#       <td id="T_88d50_row2_col2" class="data row2 col2" >0.9008</td>
#       <td id="T_88d50_row2_col3" class="data row2 col3" >0.8758</td>
#       <td id="T_88d50_row2_col4" class="data row2 col4" >0.8882</td>
#       <td id="T_88d50_row2_col5" class="data row2 col5" >0.7731</td>
#       <td id="T_88d50_row2_col6" class="data row2 col6" >0.7734</td>
#     </tr>
#     <tr>
#       <th id="T_88d50_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_88d50_row3_col0" class="data row3 col0" >0.9244</td>
#       <td id="T_88d50_row3_col1" class="data row3 col1" >0.9807</td>
#       <td id="T_88d50_row3_col2" class="data row3 col2" >0.9311</td>
#       <td id="T_88d50_row3_col3" class="data row3 col3" >0.9187</td>
#       <td id="T_88d50_row3_col4" class="data row3 col4" >0.9249</td>
#       <td id="T_88d50_row3_col5" class="data row3 col5" >0.8487</td>
#       <td id="T_88d50_row3_col6" class="data row3 col6" >0.8488</td>
#     </tr>
#     <tr>
#       <th id="T_88d50_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_88d50_row4_col0" class="data row4 col0" >0.9092</td>
#       <td id="T_88d50_row4_col1" class="data row4 col1" >0.9733</td>
#       <td id="T_88d50_row4_col2" class="data row4 col2" >0.9227</td>
#       <td id="T_88d50_row4_col3" class="data row4 col3" >0.8985</td>
#       <td id="T_88d50_row4_col4" class="data row4 col4" >0.9104</td>
#       <td id="T_88d50_row4_col5" class="data row4 col5" >0.8185</td>
#       <td id="T_88d50_row4_col6" class="data row4 col6" >0.8188</td>
#     </tr>
#     <tr>
#       <th id="T_88d50_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_88d50_row5_col0" class="data row5 col0" >0.8992</td>
#       <td id="T_88d50_row5_col1" class="data row5 col1" >0.9719</td>
#       <td id="T_88d50_row5_col2" class="data row5 col2" >0.8908</td>
#       <td id="T_88d50_row5_col3" class="data row5 col3" >0.9060</td>
#       <td id="T_88d50_row5_col4" class="data row5 col4" >0.8983</td>
#       <td id="T_88d50_row5_col5" class="data row5 col5" >0.7983</td>
#       <td id="T_88d50_row5_col6" class="data row5 col6" >0.7984</td>
#     </tr>
#     <tr>
#       <th id="T_88d50_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_88d50_row6_col0" class="data row6 col0" >0.9025</td>
#       <td id="T_88d50_row6_col1" class="data row6 col1" >0.9744</td>
#       <td id="T_88d50_row6_col2" class="data row6 col2" >0.9008</td>
#       <td id="T_88d50_row6_col3" class="data row6 col3" >0.9039</td>
#       <td id="T_88d50_row6_col4" class="data row6 col4" >0.9024</td>
#       <td id="T_88d50_row6_col5" class="data row6 col5" >0.8050</td>
#       <td id="T_88d50_row6_col6" class="data row6 col6" >0.8050</td>
#     </tr>
#     <tr>
#       <th id="T_88d50_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_88d50_row7_col0" class="data row7 col0" >0.9034</td>
#       <td id="T_88d50_row7_col1" class="data row7 col1" >0.9757</td>
#       <td id="T_88d50_row7_col2" class="data row7 col2" >0.9126</td>
#       <td id="T_88d50_row7_col3" class="data row7 col3" >0.8960</td>
#       <td id="T_88d50_row7_col4" class="data row7 col4" >0.9042</td>
#       <td id="T_88d50_row7_col5" class="data row7 col5" >0.8067</td>
#       <td id="T_88d50_row7_col6" class="data row7 col6" >0.8069</td>
#     </tr>
#     <tr>
#       <th id="T_88d50_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_88d50_row8_col0" class="data row8 col0" >0.8992</td>
#       <td id="T_88d50_row8_col1" class="data row8 col1" >0.9711</td>
#       <td id="T_88d50_row8_col2" class="data row8 col2" >0.9025</td>
#       <td id="T_88d50_row8_col3" class="data row8 col3" >0.8965</td>
#       <td id="T_88d50_row8_col4" class="data row8 col4" >0.8995</td>
#       <td id="T_88d50_row8_col5" class="data row8 col5" >0.7983</td>
#       <td id="T_88d50_row8_col6" class="data row8 col6" >0.7983</td>
#     </tr>
#     <tr>
#       <th id="T_88d50_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_88d50_row9_col0" class="data row9 col0" >0.8992</td>
#       <td id="T_88d50_row9_col1" class="data row9 col1" >0.9743</td>
#       <td id="T_88d50_row9_col2" class="data row9 col2" >0.9160</td>
#       <td id="T_88d50_row9_col3" class="data row9 col3" >0.8862</td>
#       <td id="T_88d50_row9_col4" class="data row9 col4" >0.9008</td>
#       <td id="T_88d50_row9_col5" class="data row9 col5" >0.7983</td>
#       <td id="T_88d50_row9_col6" class="data row9 col6" >0.7988</td>
#     </tr>
#     <tr>
#       <th id="T_88d50_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_88d50_row10_col0" class="data row10 col0" >0.9012</td>
#       <td id="T_88d50_row10_col1" class="data row10 col1" >0.9728</td>
#       <td id="T_88d50_row10_col2" class="data row10 col2" >0.9074</td>
#       <td id="T_88d50_row10_col3" class="data row10 col3" >0.8964</td>
#       <td id="T_88d50_row10_col4" class="data row10 col4" >0.9018</td>
#       <td id="T_88d50_row10_col5" class="data row10 col5" >0.8024</td>
#       <td id="T_88d50_row10_col6" class="data row10 col6" >0.8025</td>
#     </tr>
#     <tr>
#       <th id="T_88d50_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_88d50_row11_col0" class="data row11 col0" >0.0097</td>
#       <td id="T_88d50_row11_col1" class="data row11 col1" >0.0040</td>
#       <td id="T_88d50_row11_col2" class="data row11 col2" >0.0130</td>
#       <td id="T_88d50_row11_col3" class="data row11 col3" >0.0122</td>
#       <td id="
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]
# <style type="text/css">
# #T_ec45e_row10_col0, #T_ec45e_row10_col1, #T_ec45e_row10_col2, #T_ec45e_row10_col3, #T_ec45e_row10_col4, #T_ec45e_row10_col5, #T_ec45e_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_ec45e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec45e_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_ec45e_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_ec45e_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_ec45e_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_ec45e_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_ec45e_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_ec45e_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec45e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ec45e_row0_col0" class="data row0 col0" >0.8983</td>
#       <td id="T_ec45e_row0_col1" class="data row0 col1" >0.9709</td>
#       <td id="T_ec45e_row0_col2" class="data row0 col2" >0.9176</td>
#       <td id="T_ec45e_row0_col3" class="data row0 col3" >0.8835</td>
#       <td id="T_ec45e_row0_col4" class="data row0 col4" >0.9002</td>
#       <td id="T_ec45e_row0_col5" class="data row0 col5" >0.7966</td>
#       <td id="T_ec45e_row0_col6" class="data row0 col6" >0.7972</td>
#     </tr>
#     <tr>
#       <th id="T_ec45e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ec45e_row1_col0" class="data row1 col0" >0.8975</td>
#       <td id="T_ec45e_row1_col1" class="data row1 col1" >0.9735</td>
#       <td id="T_ec45e_row1_col2" class="data row1 col2" >0.9462</td>
#       <td id="T_ec45e_row1_col3" class="data row1 col3" >0.8622</td>
#       <td id="T_ec45e_row1_col4" class="data row1 col4" >0.9022</td>
#       <td id="T_ec45e_row1_col5" class="data row1 col5" >0.7950</td>
#       <td id="T_ec45e_row1_col6" class="data row1 col6" >0.7988</td>
#     </tr>
#     <tr>
#       <th id="T_ec45e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ec45e_row2_col0" class="data row2 col0" >0.8882</td>
#       <td id="T_ec45e_row2_col1" class="data row2 col1" >0.9674</td>
#       <td id="T_ec45e_row2_col2" class="data row2 col2" >0.9462</td>
#       <td id="T_ec45e_row2_col3" class="data row2 col3" >0.8479</td>
#       <td id="T_ec45e_row2_col4" class="data row2 col4" >0.8944</td>
#       <td id="T_ec45e_row2_col5" class="data row2 col5" >0.7765</td>
#       <td id="T_ec45e_row2_col6" class="data row2 col6" >0.7817</td>
#     </tr>
#     <tr>
#       <th id="T_ec45e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ec45e_row3_col0" class="data row3 col0" >0.9118</td>
#       <td id="T_ec45e_row3_col1" class="data row3 col1" >0.9790</td>
#       <td id="T_ec45e_row3_col2" class="data row3 col2" >0.9412</td>
#       <td id="T_ec45e_row3_col3" class="data row3 col3" >0.8889</td>
#       <td id="T_ec45e_row3_col4" class="data row3 col4" >0.9143</td>
#       <td id="T_ec45e_row3_col5" class="data row3 col5" >0.8235</td>
#       <td id="T_ec45e_row3_col6" class="data row3 col6" >0.8250</td>
#     </tr>
#     <tr>
#       <th id="T_ec45e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ec45e_row4_col0" class="data row4 col0" >0.9034</td>
#       <td id="T_ec45e_row4_col1" class="data row4 col1" >0.9748</td>
#       <td id="T_ec45e_row4_col2" class="data row4 col2" >0.9546</td>
#       <td id="T_ec45e_row4_col3" class="data row4 col3" >0.8659</td>
#       <td id="T_ec45e_row4_col4" class="data row4 col4" >0.9081</td>
#       <td id="T_ec45e_row4_col5" class="data row4 col5" >0.8067</td>
#       <td id="T_ec45e_row4_col6" class="data row4 col6" >0.8110</td>
#     </tr>
#     <tr>
#       <th id="T_ec45e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ec45e_row5_col0" class="data row5 col0" >0.9076</td>
#       <td id="T_ec45e_row5_col1" class="data row5 col1" >0.9744</td>
#       <td id="T_ec45e_row5_col2" class="data row5 col2" >0.9412</td>
#       <td id="T_ec45e_row5_col3" class="data row5 col3" >0.8819</td>
#       <td id="T_ec45e_row5_col4" class="data row5 col4" >0.9106</td>
#       <td id="T_ec45e_row5_col5" class="data row5 col5" >0.8151</td>
#       <td id="T_ec45e_row5_col6" class="data row5 col6" >0.8170</td>
#     </tr>
#     <tr>
#       <th id="T_ec45e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ec45e_row6_col0" class="data row6 col0" >0.9025</td>
#       <td id="T_ec45e_row6_col1" class="data row6 col1" >0.9732</td>
#       <td id="T_ec45e_row6_col2" class="data row6 col2" >0.9479</td>
#       <td id="T_ec45e_row6_col3" class="data row6 col3" >0.8690</td>
#       <td id="T_ec45e_row6_col4" class="data row6 col4" >0.9068</td>
#       <td id="T_ec45e_row6_col5" class="data row6 col5" >0.8050</td>
#       <td id="T_ec45e_row6_col6" class="data row6 col6" >0.8084</td>
#     </tr>
#     <tr>
#       <th id="T_ec45e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ec45e_row7_col0" class="data row7 col0" >0.9101</td>
#       <td id="T_ec45e_row7_col1" class="data row7 col1" >0.9767</td>
#       <td id="T_ec45e_row7_col2" class="data row7 col2" >0.9513</td>
#       <td id="T_ec45e_row7_col3" class="data row7 col3" >0.8789</td>
#       <td id="T_ec45e_row7_col4" class="data row7 col4" >0.9136</td>
#       <td id="T_ec45e_row7_col5" class="data row7 col5" >0.8202</td>
#       <td id="T_ec45e_row7_col6" class="data row7 col6" >0.8230</td>
#     </tr>
#     <tr>
#       <th id="T_ec45e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ec45e_row8_col0" class="data row8 col0" >0.8966</td>
#       <td id="T_ec45e_row8_col1" class="data row8 col1" >0.9727</td>
#       <td id="T_ec45e_row8_col2" class="data row8 col2" >0.9294</td>
#       <td id="T_ec45e_row8_col3" class="data row8 col3" >0.8722</td>
#       <td id="T_ec45e_row8_col4" class="data row8 col4" >0.8999</td>
#       <td id="T_ec45e_row8_col5" class="data row8 col5" >0.7933</td>
#       <td id="T_ec45e_row8_col6" class="data row8 col6" >0.7950</td>
#     </tr>
#     <tr>
#       <th id="T_ec45e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ec45e_row9_col0" class="data row9 col0" >0.9067</td>
#       <td id="T_ec45e_row9_col1" class="data row9 col1" >0.9757</td>
#       <td id="T_ec45e_row9_col2" class="data row9 col2" >0.9513</td>
#       <td id="T_ec45e_row9_col3" class="data row9 col3" >0.8735</td>
#       <td id="T_ec45e_row9_col4" class="data row9 col4" >0.9107</td>
#       <td id="T_ec45e_row9_col5" class="data row9 col5" >0.8134</td>
#       <td id="T_ec45e_row9_col6" class="data row9 col6" >0.8167</td>
#     </tr>
#     <tr>
#       <th id="T_ec45e_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_ec45e_row10_col0" class="data row10 col0" >0.9023</td>
#       <td id="T_ec45e_row10_col1" class="data row10 col1" >0.9738</td>
#       <td id="T_ec45e_row10_col2" class="data row10 col2" >0.9427</td>
#       <td id="T_ec45e_row10_col3" class="data row10 col3" >0.8724</td>
#       <td id="T_ec45e_row10_col4" class="data row10 col4" >0.9061</td>
#       <td id="T_ec45e_row10_col5" class="data row10 col5" >0.8045</td>
#       <td id="T_ec45e_row10_col6" class="data row10 col6" >0.8074</td>
#     </tr>
#     <tr>
#       <th id="T_ec45e_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_ec45e_row11_col0" class="data row11 col0" >0.0068</td>
#       <td id="T_ec45e_row11_col1" class="data row11 col1" >0.0030</td>
#       <td id="T_ec45e_row11_col2" class="data row11 col2" >0.0107</td>
#       <td id="T_ec45e_row11_col3" class="data row11 col3" >0.0113</td>
#       <td id="
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
save_model(tuned_rf_model, 'model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['age', 'hypertension',
#                                               'heart_disease', 'bmi',
#                                               'HbA1c_level',
#                                               'blood_glucose_level',
#                                               'gender_Female', 'gender_Male'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean',...
#                   RandomForestClassifier(bootstrap=False, ccp_alpha=0.0,
#                                          class_weight='balanced_subsample',
#                                          criterion='entropy', max_depth=8,
#                                          max_features=1.0, max_leaf_nodes=None,
#                                          max_samples=None,
#                                          min_impurity_decrease=0.001,
#                                          min_samples_leaf=6, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          n_estimators=290, n_jobs=-1,
#                                          oob_score=False, random_state=4254,
#                                          verbose=0, warm_start=False))],
#           verbose=False),
#  'model.pkl')
